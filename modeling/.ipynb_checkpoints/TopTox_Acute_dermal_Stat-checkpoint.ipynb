# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from sklearn.neighbors import KNeighborsClassifier
from modAL.models import ActiveLearner
#Modeling tools
exec(open('tools/modeling.py').read())
import numpy as np
import pandas as pd
from rdkit import Chem
from rdkit.Chem.Descriptors import MolLogP
from sklearn.metrics import confusion_matrix,accuracy_score,f1_score
from rdkit.Chem.AllChem import GetMorganFingerprintAsBitVect
from rdkit.Chem import Descriptors
import sys
import multiprocessing
from standardiser import break_bonds, neutralise, rules, unsalt
from standardiser.utils import StandardiseException, sanity_check
from rdkit.Chem import AllChem as Chem
from rdkit.Chem import Draw
from rdkit.Chem.Draw import IPythonConsole
from sklearn.externals import joblib


import sys
def warn(*args, **kwargs):
    pass  # to suppress sklearn warnings
import warnings
warnings.filterwarnings("ignore")
warnings.warn = warn
#Modeling tools
exec(open('tools/modeling.py').read())
from rdkit.Chem.Descriptors import MolLogP
from rdkit.Chem import Descriptors
from tools import tools
from tools import  pipeline as p
from tools import  sar
from sklearn.metrics import cohen_kappa_score
import csv
from rdkit.Chem import MACCSkeys
from sklearn.model_selection import ShuffleSplit
import _pickle as cPickle
from sklearn.model_selection import RepeatedStratifiedKFold
from sklearn.model_selection import StratifiedShuffleSplit
import bz2
from glob import glob
import _pickle as cPickle
import pickle
from sklearn.model_selection import train_test_split
import seaborn as sns
from sklearn.model_selection import train_test_split
# Out:
# Using TensorFlow backend.
#   * could not import Bokeh, plotting with Highcharts instead.
# - no local installation of highcharts found, using web version.
# - loading highcharts...
# /home/rodolpho/miniconda3/lib/python3.7/site-packages/sklearn/externals/joblib/__init__.py:15: DeprecationWarning: sklearn.externals.joblib is deprecated in 0.21 and will be removed in 0.23. Please import this functionality directly from joblib, which can be installed with: pip install joblib. If this warning is raised when loading pickled models, you may need to re-serialize those models with scikit-learn 0.21+.
#   warnings.warn(msg, category=DeprecationWarning)
# <script src="http://code.highcharts.com/highcharts.js"></script>
# <script src="http://code.highcharts.com/highcharts-more.js"></script>
# <script src="http://code.highcharts.com/modules/heatmap.js"></script>
# <script src="http://code.highcharts.com/modules/exporting.js"></script>
# * SA scorer not available. RDKit's Contrib dir needs to be in the Python import path...
# tools.tools                                   (190829-08:16)
# - no local installation of JSME found, using web version.
# * SA scorer not available. RDKit's Contrib dir needs to be in the Python import path...
# > interactive IPython session.
# tools.sar                                     (190829-08:16)

# %% [markdown]
#  # Acute Inhalation

# %% [markdown]
# ##  Acute Inhalation - Morgan

# %%
acute_inhalation = joblib.load('Projeto_5_Acute_dermal/model/Modelo_acute_dermal_morgan.pkl')
acute_inhalation_data= pd.read_pickle('Projeto_5_Acute_dermal/model/Dados_adicionais_acute_dermal_morgan.pbz2', compression="bz2")
moldf= acute_inhalation_data['molDF']
del moldf['mol']
moldf.head()
# Out:
#                                             Outcome Prediction  Confiability
# SMILES
# BrCCBr                                          1.0      Toxic          82.0
# Br[As](Br)c1ccccc1                              1.0      Toxic          92.0
# C#CCC1=C(C)C(OC(=O)C2C(C=C(C)C)C2(C)C)CC1=O     0.0      Toxic          51.0
# C#CCOC(=O)C(C)Oc1ccc(Oc2ncc(Cl)cc2F)cc1         0.0  Non-Toxic          75.0
# C#CCOS(=O)OC1CCCCC1Oc1ccc(C(C)(C)C)cc1          1.0  Non-Toxic          62.0

# %%
#
moldf['Outcome']=np.where(moldf['Outcome'] >= '1', 1, -1)
moldf['Prediction']=np.where(moldf['Prediction']== 'Toxic', 1, -1)
moldf['Confiability']= moldf['Confiability'].values/100
#
moldf_acute_inhalation = moldf.copy()
#del moldf_acute_inhalation['Outcome']
moldf_acute_inhalation = moldf_acute_inhalation.rename(columns={"Prediction": "Morgan_Pred", "Confiability": "Morgan_Conf"})
fps_acute_inhalation_morgan= np.vstack(acute_inhalation_data['fpDF']['FingerPrint'].values)
X, y = train_test_split( fps_acute_inhalation_morgan , test_size=0.2, random_state=42)
acute_inhalation_morgan_AD_limit= (np.average(acute_inhalation_data['applM'])-(1*(np.std(acute_inhalation_data['applM']))))
acute_inhalation_morgan_K= acute_inhalation_data["k"]
acute_inhalation_morgan_AD = getNeighborsDitance(X,fps_acute_inhalation_morgan , acute_inhalation_morgan_K)
moldf_acute_inhalation['Morgan AD']= np.where(acute_inhalation_morgan_AD >=acute_inhalation_morgan_AD_limit, 1, 0)
moldf_acute_inhalation.head()
# Out:
#                                              Outcome  Morgan_Pred  \
# SMILES
# BrCCBr                                             1            1
# Br[As](Br)c1ccccc1                                 1            1
# C#CCC1=C(C)C(OC(=O)C2C(C=C(C)C)C2(C)C)CC1=O       -1            1
# C#CCOC(=O)C(C)Oc1ccc(Oc2ncc(Cl)cc2F)cc1           -1           -1
# C#CCOS(=O)OC1CCCCC1Oc1ccc(C(C)(C)C)cc1             1           -1
#
#                                              Morgan_Conf  Morgan AD
# SMILES
# BrCCBr                                              0.82          1
# Br[As](Br)c1ccccc1                                  0.92          1
# C#CCC1=C(C)C(OC(=O)C2C(C=C(C)C)C2(C)C)CC1=O         0.51          0
# C#CCOC(=O)C(C)Oc1ccc(Oc2ncc(Cl)cc2F)cc1             0.75          0
# C#CCOS(=O)OC1CCCCC1Oc1ccc(C(C)(C)C)cc1              0.62          1

# %%
moldf_acute_inhalation['Morgan Pred'] = moldf_acute_inhalation[['Morgan_Pred', 'Morgan_Conf']].prod(1)
moldf_acute_inhalation['Morgan Pred AD'] = moldf_acute_inhalation[['Morgan_Pred', 'Morgan_Conf','Morgan AD']].prod(1)
moldf_acute_inhalation.head()
moldf_acute_inhalation_morgan= moldf_acute_inhalation[['Outcome','Morgan Pred', 'Morgan Pred AD']]
moldf_acute_inhalation_morgan.head()
# Out:
#                                              Outcome  Morgan Pred  \
# SMILES
# BrCCBr                                             1         0.82
# Br[As](Br)c1ccccc1                                 1         0.92
# C#CCC1=C(C)C(OC(=O)C2C(C=C(C)C)C2(C)C)CC1=O       -1         0.51
# C#CCOC(=O)C(C)Oc1ccc(Oc2ncc(Cl)cc2F)cc1           -1        -0.75
# C#CCOS(=O)OC1CCCCC1Oc1ccc(C(C)(C)C)cc1             1        -0.62
#
#                                              Morgan Pred AD
# SMILES
# BrCCBr                                                 0.82
# Br[As](Br)c1ccccc1                                     0.92
# C#CCC1=C(C)C(OC(=O)C2C(C=C(C)C)C2(C)C)CC1=O            0.00
# C#CCOC(=O)C(C)Oc1ccc(Oc2ncc(Cl)cc2F)cc1               -0.00
# C#CCOS(=O)OC1CCCCC1Oc1ccc(C(C)(C)C)cc1                -0.62

# %% [markdown]
# ##  Acute Inhalation - MACCS

# %%
acute_inhalation_maccs = joblib.load('Projeto_5_Acute_dermal/model/Modelo_acute_dermal_MACCS.pkl')
acute_inhalation_data_maccs= pd.read_pickle('Projeto_5_Acute_dermal/model/Dados_adicionais_acute_dermal_MACCS.pbz2', compression="bz2")
moldf= acute_inhalation_data_maccs['molDF']
del moldf['mol']
moldf.head()
# Out:
#                                             Outcome Prediction  Confiability
# SMILES
# BrCCBr                                          1.0      Toxic          53.8
# Br[As](Br)c1ccccc1                              1.0      Toxic          88.0
# C#CCC1=C(C)C(OC(=O)C2C(C=C(C)C)C2(C)C)CC1=O     0.0  Non-Toxic          52.8
# C#CCOC(=O)C(C)Oc1ccc(Oc2ncc(Cl)cc2F)cc1         0.0  Non-Toxic          68.0
# C#CCOS(=O)OC1CCCCC1Oc1ccc(C(C)(C)C)cc1          1.0  Non-Toxic          61.4

# %%
#
moldf['Outcome']=np.where(moldf['Outcome'] >= '1', 1, -1)
moldf['Prediction']=np.where(moldf['Prediction']== 'Toxic', 1, -1)
moldf['Confiability']= moldf['Confiability'].values/100
#
moldf_acute_inhalation_maccs = moldf.copy()
#del moldf_acute_inhalation['Outcome']
moldf_acute_inhalation_maccs= moldf_acute_inhalation_maccs.rename(columns={"Prediction": "MACCS_Pred", "Confiability": "MACCS_Conf"})
fps_acute_inhalation_maccs= np.vstack(acute_inhalation_data_maccs['fpDF']['FingerPrint'].values)
X, y = train_test_split( fps_acute_inhalation_maccs , test_size=0.2, random_state=42)
acute_inhalation_maccs_AD_limit= (np.average(acute_inhalation_data_maccs['applM'])-(1*(np.std(acute_inhalation_data_maccs['applM']))))
acute_inhalation_maccs_K= acute_inhalation_data_maccs["k"]
acute_inhalation_maccs_AD = getNeighborsDitance(X,fps_acute_inhalation_maccs , acute_inhalation_maccs_K)
moldf_acute_inhalation_maccs['MACCS AD']= np.where(acute_inhalation_maccs_AD >=acute_inhalation_maccs_AD_limit, 1, 0)
moldf_acute_inhalation_maccs.head(100)
# Out:
#                                              Outcome  MACCS_Pred  MACCS_Conf  \
# SMILES
# BrCCBr                                             1           1       0.538
# Br[As](Br)c1ccccc1                                 1           1       0.880
# C#CCC1=C(C)C(OC(=O)C2C(C=C(C)C)C2(C)C)CC1=O       -1          -1       0.528
# C#CCOC(=O)C(C)Oc1ccc(Oc2ncc(Cl)cc2F)cc1           -1          -1       0.680
# C#CCOS(=O)OC1CCCCC1Oc1ccc(C(C)(C)C)cc1             1          -1       0.614
# ...                                              ...         ...         ...
# CC(Cc1ccc(C(C)(C)C)cc1)CN1CC(C)OC(C)C1            -1          -1       0.508
# CC(Cc1ccc(O)cc1)NCC(=O)c1cc(O)cc(O)c1             -1          -1       0.696
# CC(N)=NP(=S)(Oc1ccc(Cl)cc1)Oc1ccc(Cl)cc1           1           1       0.700
# CC(NC(=O)C(C)NC(=O)C(N)CCP(C)(=O)O)C(=O)O         -1          -1       0.706
# CC(O)CN(C)C                                        1          -1       0.584
#
#                                              MACCS AD
# SMILES
# BrCCBr                                              1
# Br[As](Br)c1ccccc1                                  1
# C#CCC1=C(C)C(OC(=O)C2C(C=C(C)C)C2(C)C)CC1=O         1
# C#CCOC(=O)C(C)Oc1ccc(Oc2ncc(Cl)cc2F)cc1             1
# C#CCOS(=O)OC1CCCCC1Oc1ccc(C(C)(C)C)cc1              1
# ...                                               ...
# CC(Cc1ccc(C(C)(C)C)cc1)CN1CC(C)OC(C)C1              1
# CC(Cc1ccc(O)cc1)NCC(=O)c1cc(O)cc(O)c1               1
# CC(N)=NP(=S)(Oc1ccc(Cl)cc1)Oc1ccc(Cl)cc1            1
# CC(NC(=O)C(C)NC(=O)C(N)CCP(C)(=O)O)C(=O)O           1
# CC(O)CN(C)C                                         1
#
# [100 rows x 4 columns]

# %%
moldf_acute_inhalation_maccs['MACCS Pred'] = moldf_acute_inhalation_maccs[['MACCS_Pred', 'MACCS_Conf']].prod(1)
moldf_acute_inhalation_maccs['MACCS Pred AD'] = moldf_acute_inhalation_maccs[['MACCS_Pred', 'MACCS_Conf','MACCS AD']].prod(1)
moldf_acute_inhalation_maccs.head()
moldf_acute_inhalation_maccs= moldf_acute_inhalation_maccs[['Outcome','MACCS Pred', 'MACCS Pred AD']]
del moldf_acute_inhalation_maccs['Outcome']
moldf_acute_inhalation_maccs.head(200)
# Out:
#                                               MACCS Pred  MACCS Pred AD
# SMILES
# BrCCBr                                             0.538          0.538
# Br[As](Br)c1ccccc1                                 0.880          0.880
# C#CCC1=C(C)C(OC(=O)C2C(C=C(C)C)C2(C)C)CC1=O       -0.528         -0.528
# C#CCOC(=O)C(C)Oc1ccc(Oc2ncc(Cl)cc2F)cc1           -0.680         -0.680
# C#CCOS(=O)OC1CCCCC1Oc1ccc(C(C)(C)C)cc1            -0.614         -0.614
# ...                                                  ...            ...
# CCCCN(C=O)CCCC                                    -0.774         -0.000
# CCCCN(CCCC)C(=S)S                                  0.612          0.612
# CCCCN1CCCC1=O                                     -0.712         -0.000
# CCCCOC(=O)C(C)Oc1ccc(Oc2ccc(C(F)(F)F)cn2)cc1      -0.776         -0.776
# CCCCOC(=O)C1(O)c2ccccc2-c2ccccc21                 -0.608         -0.608
#
# [200 rows x 2 columns]

# %% [markdown]
# ##  Acute Inhalation - mordred

# %%
acute_inhalation_modred = joblib.load('Projeto_5_Acute_dermal/model/Modelo_Acute_dermal_mordred.pkl')
acute_inhalation_data_mordred= pd.read_pickle('Projeto_5_Acute_dermal/model/Dados_adicionais_Acute_dermal_mordred.pbz2', compression="bz2")
moldf= acute_inhalation_data_mordred['molDF']
del moldf['mol']
moldf.head()
# Out:
#                                             Outcome Prediction  Confiability
# SMILES
# BrCCBr                                          1.0      Toxic          58.0
# Br[As](Br)c1ccccc1                              1.0      Toxic          85.4
# C#CCC1=C(C)C(OC(=O)C2C(C=C(C)C)C2(C)C)CC1=O     0.0      Toxic          63.0
# C#CCOC(=O)C(C)Oc1ccc(Oc2ncc(Cl)cc2F)cc1         0.0  Non-Toxic          70.8
# C#CCOS(=O)OC1CCCCC1Oc1ccc(C(C)(C)C)cc1          1.0  Non-Toxic          89.0

# %%
#
moldf['Outcome']=np.where(moldf['Outcome'] >= '1', 1, -1)
moldf['Prediction']=np.where(moldf['Prediction']== 'Toxic', 1, -1)
moldf['Confiability']= moldf['Confiability'].values/100
#
moldf_acute_inhalation_mordred = moldf.copy()
#del moldf_acute_inhalation['Outcome']
moldf_acute_inhalation_mordred= moldf_acute_inhalation_mordred.rename(columns={"Prediction": "Mordred_Pred", "Confiability": "Mordred_Conf"})
fps_acute_inhalation_mordred= np.vstack(acute_inhalation_data_mordred['fpDF']['FingerPrint'].values)
X, y = train_test_split( fps_acute_inhalation_mordred , test_size=0.2, random_state=42)
acute_inhalation_mordred_AD_limit= (np.average(acute_inhalation_data_mordred['applM'])-(1*(np.std(acute_inhalation_data_mordred['applM']))))
acute_inhalation_mordred_K= acute_inhalation_data_mordred["k"]
acute_inhalation_mordred_AD = getNeighborsDitance(X,fps_acute_inhalation_mordred , acute_inhalation_mordred_K)
moldf_acute_inhalation_mordred['Mordred AD']= np.where(acute_inhalation_mordred_AD >=acute_inhalation_mordred_AD_limit, 1, 0)
moldf_acute_inhalation_mordred.head(100)
# Out:
#                                              Outcome  Mordred_Pred  \
# SMILES
# BrCCBr                                             1             1
# Br[As](Br)c1ccccc1                                 1             1
# C#CCC1=C(C)C(OC(=O)C2C(C=C(C)C)C2(C)C)CC1=O       -1             1
# C#CCOC(=O)C(C)Oc1ccc(Oc2ncc(Cl)cc2F)cc1           -1            -1
# C#CCOS(=O)OC1CCCCC1Oc1ccc(C(C)(C)C)cc1             1            -1
# ...                                              ...           ...
# CC(Cc1ccc(C(C)(C)C)cc1)CN1CC(C)OC(C)C1            -1            -1
# CC(Cc1ccc(O)cc1)NCC(=O)c1cc(O)cc(O)c1             -1            -1
# CC(N)=NP(=S)(Oc1ccc(Cl)cc1)Oc1ccc(Cl)cc1           1             1
# CC(NC(=O)C(C)NC(=O)C(N)CCP(C)(=O)O)C(=O)O         -1            -1
# CC(O)CN(C)C                                        1             1
#
#                                              Mordred_Conf  Mordred AD
# SMILES
# BrCCBr                                              0.580           1
# Br[As](Br)c1ccccc1                                  0.854           1
# C#CCC1=C(C)C(OC(=O)C2C(C=C(C)C)C2(C)C)CC1=O         0.630           1
# C#CCOC(=O)C(C)Oc1ccc(Oc2ncc(Cl)cc2F)cc1             0.708           1
# C#CCOS(=O)OC1CCCCC1Oc1ccc(C(C)(C)C)cc1              0.890           1
# ...                                                   ...         ...
# CC(Cc1ccc(C(C)(C)C)cc1)CN1CC(C)OC(C)C1              0.726           1
# CC(Cc1ccc(O)cc1)NCC(=O)c1cc(O)cc(O)c1               0.904           1
# CC(N)=NP(=S)(Oc1ccc(Cl)cc1)Oc1ccc(Cl)cc1            0.832           1
# CC(NC(=O)C(C)NC(=O)C(N)CCP(C)(=O)O)C(=O)O           0.810           1
# CC(O)CN(C)C                                         0.570           1
#
# [100 rows x 4 columns]

# %%
moldf_acute_inhalation_mordred['Mordred Pred'] = moldf_acute_inhalation_mordred[['Mordred_Pred', 'Mordred_Conf']].prod(1)
moldf_acute_inhalation_mordred['Mordred Pred AD'] = moldf_acute_inhalation_mordred[['Mordred_Pred', 'Mordred_Conf','Mordred AD']].prod(1)
moldf_acute_inhalation_mordred.head()
moldf_acute_inhalation_mordred= moldf_acute_inhalation_mordred[['Outcome','Mordred Pred', 'Mordred Pred AD']]
del moldf_acute_inhalation_mordred['Outcome']
moldf_acute_inhalation_mordred.head(200)
# Out:
#                                               Mordred Pred  Mordred Pred AD
# SMILES
# BrCCBr                                               0.580            0.580
# Br[As](Br)c1ccccc1                                   0.854            0.854
# C#CCC1=C(C)C(OC(=O)C2C(C=C(C)C)C2(C)C)CC1=O          0.630            0.630
# C#CCOC(=O)C(C)Oc1ccc(Oc2ncc(Cl)cc2F)cc1             -0.708           -0.708
# C#CCOS(=O)OC1CCCCC1Oc1ccc(C(C)(C)C)cc1              -0.890           -0.890
# ...                                                    ...              ...
# CCCCN(C=O)CCCC                                      -0.740           -0.740
# CCCCN(CCCC)C(=S)S                                    0.606            0.606
# CCCCN1CCCC1=O                                       -0.746           -0.746
# CCCCOC(=O)C(C)Oc1ccc(Oc2ccc(C(F)(F)F)cn2)cc1        -0.864           -0.864
# CCCCOC(=O)C1(O)c2ccccc2-c2ccccc21                   -0.524           -0.524
#
# [200 rows x 2 columns]

# %%
moldf_global=pd.concat([moldf_acute_inhalation_morgan, moldf_acute_inhalation_maccs, 
                       moldf_acute_inhalation_mordred ], axis=1, 
                      join_axes=[moldf_acute_inhalation_morgan.index])
moldf_global.head()
# Out:
#                                              Outcome  Morgan Pred  \
# SMILES
# BrCCBr                                             1         0.82
# Br[As](Br)c1ccccc1                                 1         0.92
# C#CCC1=C(C)C(OC(=O)C2C(C=C(C)C)C2(C)C)CC1=O       -1         0.51
# C#CCOC(=O)C(C)Oc1ccc(Oc2ncc(Cl)cc2F)cc1           -1        -0.75
# C#CCOS(=O)OC1CCCCC1Oc1ccc(C(C)(C)C)cc1             1        -0.62
#
#                                              Morgan Pred AD  MACCS Pred  \
# SMILES
# BrCCBr                                                 0.82       0.538
# Br[As](Br)c1ccccc1                                     0.92       0.880
# C#CCC1=C(C)C(OC(=O)C2C(C=C(C)C)C2(C)C)CC1=O            0.00      -0.528
# C#CCOC(=O)C(C)Oc1ccc(Oc2ncc(Cl)cc2F)cc1               -0.00      -0.680
# C#CCOS(=O)OC1CCCCC1Oc1ccc(C(C)(C)C)cc1                -0.62      -0.614
#
#                                              MACCS Pred AD  Mordred Pred  \
# SMILES
# BrCCBr                                               0.538         0.580
# Br[As](Br)c1ccccc1                                   0.880         0.854
# C#CCC1=C(C)C(OC(=O)C2C(C=C(C)C)C2(C)C)CC1=O         -0.528         0.630
# C#CCOC(=O)C(C)Oc1ccc(Oc2ncc(Cl)cc2F)cc1             -0.680        -0.708
# C#CCOS(=O)OC1CCCCC1Oc1ccc(C(C)(C)C)cc1              -0.614        -0.890
#
#                                              Mordred Pred AD
# SMILES
# BrCCBr                                                 0.580
# Br[As](Br)c1ccccc1                                     0.854
# C#CCC1=C(C)C(OC(=O)C2C(C=C(C)C)C2(C)C)CC1=O            0.630
# C#CCOC(=O)C(C)Oc1ccc(Oc2ncc(Cl)cc2F)cc1               -0.708
# C#CCOS(=O)OC1CCCCC1Oc1ccc(C(C)(C)C)cc1                -0.890

# %%
moldf_global['Consensus Conf'] = moldf_global[['Morgan Pred','MACCS Pred','Mordred Pred']].mean(1)
moldf_global['Consensus']=np.where(moldf_global['Consensus Conf']>= 0, 1, -1)
moldf_global['Consensus Conf AD'] = moldf_global[['Morgan Pred AD','MACCS Pred AD','Mordred Pred AD']].mean(1)
moldf_global['Consensus AD']=np.where(moldf_global['Consensus Conf AD']>= 0, 1, -1)

# %%
moldf_global
# Out:
#                                              Outcome  Morgan Pred  \
# SMILES
# BrCCBr                                             1         0.82
# Br[As](Br)c1ccccc1                                 1         0.92
# C#CCC1=C(C)C(OC(=O)C2C(C=C(C)C)C2(C)C)CC1=O       -1         0.51
# C#CCOC(=O)C(C)Oc1ccc(Oc2ncc(Cl)cc2F)cc1           -1        -0.75
# C#CCOS(=O)OC1CCCCC1Oc1ccc(C(C)(C)C)cc1             1        -0.62
# ...                                              ...          ...
# Sc1ccccc1                                          1         0.83
# c1cc(OCC2CO2)c2ccc(OCC3CO3)cc2c1                   1        -0.73
# c1cc[n+]2c(c1)-c1cccc[n+]1CC2                      1         0.78
# c1ccc2scnc2c1                                      1         0.54
# c1ncn([Sn](C2CCCCC2)(C2CCCCC2)C2CCCCC2)n1          1        -0.64
#
#                                              Morgan Pred AD  MACCS Pred  \
# SMILES
# BrCCBr                                                 0.82    0.538000
# Br[As](Br)c1ccccc1                                     0.92    0.880000
# C#CCC1=C(C)C(OC(=O)C2C(C=C(C)C)C2(C)C)CC1=O            0.00   -0.528000
# C#CCOC(=O)C(C)Oc1ccc(Oc2ncc(Cl)cc2F)cc1               -0.00   -0.680000
# C#CCOS(=O)OC1CCCCC1Oc1ccc(C(C)(C)C)cc1                -0.62   -0.614000
# ...                                                     ...         ...
# Sc1ccccc1                                              0.83    0.766000
# c1cc(OCC2CO2)c2ccc(OCC3CO3)cc2c1                      -0.73   -0.552000
# c1cc[n+]2c(c1)-c1cccc[n+]1CC2                          0.00    0.529333
# c1ccc2scnc2c1                                          0.54   -0.654000
# c1ncn([Sn](C2CCCCC2)(C2CCCCC2)C2CCCCC2)n1             -0.64   -0.538300
#
#                                              MACCS Pred AD  Mordred Pred  \
# SMILES
# BrCCBr                                              0.5380         0.580
# Br[As](Br)c1ccccc1                                  0.8800         0.854
# C#CCC1=C(C)C(OC(=O)C2C(C=C(C)C)C2(C)C)CC1=O        -0.5280         0.630
# C#CCOC(=O)C(C)Oc1ccc(Oc2ncc(Cl)cc2F)cc1            -0.6800        -0.708
# C#CCOS(=O)OC1CCCCC1Oc1ccc(C(C)(C)C)cc1             -0.6140        -0.890
# ...                                                    ...           ...
# Sc1ccccc1                                           0.7660         0.788
# c1cc(OCC2CO2)c2ccc(OCC3CO3)cc2c1                   -0.5520        -0.772
# c1cc[n+]2c(c1)-c1cccc[n+]1CC2                       0.0000        -0.556
# c1ccc2scnc2c1                                      -0.6540         0.594
# c1ncn([Sn](C2CCCCC2)(C2CCCCC2)C2CCCCC2)n1          -0.5383         0.774
#
#                                              Mordred Pred AD  Consensus Conf  \
# SMILES
# BrCCBr                                                 0.580        0.646000
# Br[As](Br)c1ccccc1                                     0.854        0.884667
# C#CCC1=C(C)C(OC(=O)C2C(C=C(C)C)C2(C)C)CC1=O            0.630        0.204000
# C#CCOC(=O)C(C)Oc1ccc(Oc2ncc(Cl)cc2F)cc1               -0.708       -0.712667
# C#CCOS(=O)OC1CCCCC1Oc1ccc(C(C)(C)C)cc1                -0.890       -0.708000
# ...                                                      ...             ...
# Sc1ccccc1                                              0.788        0.794667
# c1cc(OCC2CO2)c2ccc(OCC3CO3)cc2c1                      -0.772       -0.684667
# c1cc[n+]2c(c1)-c1cccc[n+]1CC2                         -0.000        0.251111
# c1ccc2scnc2c1                                          0.594        0.160000
# c1ncn([Sn](C2CCCCC2)(C2CCCCC2)C2CCCCC2)n1              0.774       -0.134767
#
#                                              Consensus  Consensus Conf AD  \
# SMILES
# BrCCBr                                               1           0.646000
# Br[As](Br)c1ccccc1                                   1           0.884667
# C#CCC1=C(C)C(OC(=O)C2C(C=C(C)C)C2(C)C)CC1=O          1           0.034000
# C#CCOC(=O)C(C)Oc1ccc(Oc2ncc(Cl)cc2F)cc1             -1          -0.462667
# C#CCOS(=O)OC1CCCCC1Oc1ccc(C(C)(C)C)cc1              -1          -0.708000
# ...                                                ...                ...
# Sc1ccccc1                                            1           0.794667
# c1cc(OCC2CO2)c2ccc(OCC3CO3)cc2c1                    -1          -0.684667
# c1cc[n+]2c(c1)-c1cccc[n+]1CC2                        1           0.000000
# c1ccc2scnc2c1                                        1           0.160000
# c1ncn([Sn](C2CCCCC2)(C2CCCCC2)C2CCCCC2)n1           -1          -0.134767
#
#                                              Consensus AD
# SMILES
# BrCCBr                                                  1
# Br[As](Br)c1ccccc1                                      1
# C#CCC1=C(C)C(OC(=O)C2C(C=C(C)C)C2(C)C)CC1=O             1
# C#CCOC(=O)C(C)Oc1ccc(Oc2ncc(Cl)cc2F)cc1                -1
# C#CCOS(=O)OC1CCCCC1Oc1ccc(C(C)(C)C)cc1                 -1
# ...                                                   ...
# Sc1ccccc1                                               1
# c1cc(OCC2CO2)c2ccc(OCC3CO3)cc2c1                       -1
# c1cc[n+]2c(c1)-c1cccc[n+]1CC2                           1
# c1ccc2scnc2c1                                           1
# c1ncn([Sn](C2CCCCC2)(C2CCCCC2)C2CCCCC2)n1              -1
#
# [632 rows x 11 columns]

# %%
run_statistics(moldf_global['Outcome'], moldf_global['Consensus'], label="Consensus external 5-fold CV", coverage=100)
# Out:
# ########################################
# #   Unbalanced Statistical Parameters  #
# ########################################
# Accuracy: 0.76
# Area under the Curve (AUC): 0.76
# ########################################
# #   Balanced Statistical Parameters    #
# ########################################
# Correct Classification Rate (CCR): 0.76
# Weighted Kappa:  0.52
# ########################################
# #            Positive Class            #
# ########################################
# Sensitivity (Se): 0.74
# Positive Predictive Value (PPV): 0.77
# ########################################
# #            Negative Class            #
# ########################################
# Specificity (Sp): 0.78
# Negative Predictive Value (NPV): 0.75
# ########################################
# #     Other Statistical Parameters     #
# ########################################
# Precision:  0.77
# Recall:  0.74
# F1:  0.76
# ########################################
# #        Applicability Domain          #
# ########################################
# coverage:  100%

# %%
coverage= (len(moldf_global['Consensus AD'])*100/len(moldf))
run_statistics(moldf_global['Outcome'], moldf_global['Consensus AD'], 
               label="Consensus AD external 5-fold CV", coverage=int(coverage))
# Out:
# ########################################
# #   Unbalanced Statistical Parameters  #
# ########################################
# Accuracy: 0.74
# Area under the Curve (AUC): 0.74
# ########################################
# #   Balanced Statistical Parameters    #
# ########################################
# Correct Classification Rate (CCR): 0.74
# Weighted Kappa:  0.48
# ########################################
# #            Positive Class            #
# ########################################
# Sensitivity (Se): 0.75
# Positive Predictive Value (PPV): 0.73
# ########################################
# #            Negative Class            #
# ########################################
# Specificity (Sp): 0.73
# Negative Predictive Value (NPV): 0.74
# ########################################
# #     Other Statistical Parameters     #
# ########################################
# Precision:  0.73
# Recall:  0.75
# F1:  0.74
# ########################################
# #        Applicability Domain          #
# ########################################
# coverage:  100%
