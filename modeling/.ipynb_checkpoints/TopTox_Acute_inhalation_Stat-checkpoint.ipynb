# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from sklearn.neighbors import KNeighborsClassifier
from modAL.models import ActiveLearner
#Modeling tools
exec(open('tools/modeling.py').read())
import numpy as np
import pandas as pd
from rdkit import Chem
from rdkit.Chem.Descriptors import MolLogP
from sklearn.metrics import confusion_matrix,accuracy_score,f1_score
from rdkit.Chem.AllChem import GetMorganFingerprintAsBitVect
from rdkit.Chem import Descriptors
import sys
import multiprocessing
from standardiser import break_bonds, neutralise, rules, unsalt
from standardiser.utils import StandardiseException, sanity_check
from rdkit.Chem import AllChem as Chem
from rdkit.Chem import Draw
from rdkit.Chem.Draw import IPythonConsole
from sklearn.externals import joblib


import sys
def warn(*args, **kwargs):
    pass  # to suppress sklearn warnings
import warnings
warnings.filterwarnings("ignore")
warnings.warn = warn
#Modeling tools
exec(open('tools/modeling.py').read())
from rdkit.Chem.Descriptors import MolLogP
from rdkit.Chem import Descriptors
from tools import tools
from tools import  pipeline as p
from tools import  sar
from sklearn.metrics import cohen_kappa_score
import csv
from rdkit.Chem import MACCSkeys
from sklearn.model_selection import ShuffleSplit
import _pickle as cPickle
from sklearn.model_selection import RepeatedStratifiedKFold
from sklearn.model_selection import StratifiedShuffleSplit
import bz2
from glob import glob
import _pickle as cPickle
import pickle
from sklearn.model_selection import train_test_split
import seaborn as sns
from sklearn.model_selection import train_test_split

# %% [markdown]
#  # Acute Inhalation

# %% [markdown]
# ##  Acute Inhalation - Morgan

# %%
acute_inhalation = joblib.load('Projeto_2_Acute_Inhalation/model/Modelo_acute_inhal_morgan_new_data.pkl')
acute_inhalation_data= pd.read_pickle('Projeto_2_Acute_Inhalation/model/Dados_adicionais_acute_inhal_morgan_new_data.pbz2', compression="bz2")
moldf= acute_inhalation_data['molDF']
del moldf['mol']
moldf.head()
# Out:
#                                                    Outcome Prediction  \
# SMILES
# BrC1CC(Br)CC(Br)CC(Br)CC(Br)CC(Br)C1                     0      Toxic
# Brc1c(Br)c(Br)c(Oc2c(Br)c(Br)c(Br)c(Br)c2Br)c(B...       0  Non-Toxic
# Brc1ccccc1                                               0  Non-Toxic
# C#CC(C)(C)O                                              0      Toxic
# C#CC(C)O                                                 1      Toxic
#
#                                                     Confiability
# SMILES
# BrC1CC(Br)CC(Br)CC(Br)CC(Br)CC(Br)C1                        61.0
# Brc1c(Br)c(Br)c(Oc2c(Br)c(Br)c(Br)c(Br)c2Br)c(B...          78.0
# Brc1ccccc1                                                  75.0
# C#CC(C)(C)O                                                 57.0
# C#CC(C)O                                                    74.0

# %%
#
moldf['Outcome']=np.where(moldf['Outcome'] >= '1', 1, -1)
moldf['Prediction']=np.where(moldf['Prediction']== 'Toxic', 1, -1)
moldf['Confiability']= moldf['Confiability'].values/100
#
moldf_acute_inhalation = moldf.copy()
#del moldf_acute_inhalation['Outcome']
moldf_acute_inhalation = moldf_acute_inhalation.rename(columns={"Prediction": "Morgan_Pred", "Confiability": "Morgan_Conf"})
fps_acute_inhalation_morgan= np.vstack(acute_inhalation_data['fpDF']['FingerPrint'].values)
X, y = train_test_split( fps_acute_inhalation_morgan , test_size=0.2, random_state=42)
acute_inhalation_morgan_AD_limit= (np.average(acute_inhalation_data['applM'])-(1*(np.std(acute_inhalation_data['applM']))))
acute_inhalation_morgan_K= acute_inhalation_data["k"]
acute_inhalation_morgan_AD = getNeighborsDitance(X,fps_acute_inhalation_morgan , acute_inhalation_morgan_K)
moldf_acute_inhalation['Morgan AD']= np.where(acute_inhalation_morgan_AD >=acute_inhalation_morgan_AD_limit, 1, 0)
moldf_acute_inhalation.head()
# Out:
#                                                     Outcome  Morgan_Pred  \
# SMILES
# BrC1CC(Br)CC(Br)CC(Br)CC(Br)CC(Br)C1                     -1            1
# Brc1c(Br)c(Br)c(Oc2c(Br)c(Br)c(Br)c(Br)c2Br)c(B...       -1           -1
# Brc1ccccc1                                               -1           -1
# C#CC(C)(C)O                                              -1            1
# C#CC(C)O                                                  1            1
#
#                                                     Morgan_Conf  Morgan AD
# SMILES
# BrC1CC(Br)CC(Br)CC(Br)CC(Br)CC(Br)C1                       0.61          1
# Brc1c(Br)c(Br)c(Oc2c(Br)c(Br)c(Br)c(Br)c2Br)c(B...         0.78          1
# Brc1ccccc1                                                 0.75          1
# C#CC(C)(C)O                                                0.57          0
# C#CC(C)O                                                   0.74          1

# %%
moldf_acute_inhalation['Morgan Pred'] = moldf_acute_inhalation[['Morgan_Pred', 'Morgan_Conf']].prod(1)
moldf_acute_inhalation['Morgan Pred AD'] = moldf_acute_inhalation[['Morgan_Pred', 'Morgan_Conf','Morgan AD']].prod(1)
moldf_acute_inhalation.head()
moldf_acute_inhalation_morgan= moldf_acute_inhalation[['Outcome','Morgan Pred', 'Morgan Pred AD']]
moldf_acute_inhalation_morgan.head()
# Out:
#                                                     Outcome  Morgan Pred  \
# SMILES
# BrC1CC(Br)CC(Br)CC(Br)CC(Br)CC(Br)C1                     -1         0.61
# Brc1c(Br)c(Br)c(Oc2c(Br)c(Br)c(Br)c(Br)c2Br)c(B...       -1        -0.78
# Brc1ccccc1                                               -1        -0.75
# C#CC(C)(C)O                                              -1         0.57
# C#CC(C)O                                                  1         0.74
#
#                                                     Morgan Pred AD
# SMILES
# BrC1CC(Br)CC(Br)CC(Br)CC(Br)CC(Br)C1                          0.61
# Brc1c(Br)c(Br)c(Oc2c(Br)c(Br)c(Br)c(Br)c2Br)c(B...           -0.78
# Brc1ccccc1                                                   -0.75
# C#CC(C)(C)O                                                   0.00
# C#CC(C)O                                                      0.74

# %% [markdown]
# ##  Acute Inhalation - MACCS

# %%
acute_inhalation_maccs = joblib.load('Projeto_2_Acute_Inhalation/model/Modelo_acute_inhal_MACCS.pkl')
acute_inhalation_data_maccs= pd.read_pickle('Projeto_2_Acute_Inhalation/model/Dados_adicionais_acute_inhal_MACCS.pbz2', compression="bz2")
moldf= acute_inhalation_data_maccs['molDF']
del moldf['mol']
moldf.head()
# Out:
#                                                    Outcome Prediction  \
# SMILES
# BrC1CC(Br)CC(Br)CC(Br)CC(Br)CC(Br)C1                     0  Non-Toxic
# Brc1c(Br)c(Br)c(Oc2c(Br)c(Br)c(Br)c(Br)c2Br)c(B...       0  Non-Toxic
# Brc1ccccc1                                               0  Non-Toxic
# C#CC(C)(C)O                                              0  Non-Toxic
# C#CC(C)O                                                 1  Non-Toxic
#
#                                                     Confiability
# SMILES
# BrC1CC(Br)CC(Br)CC(Br)CC(Br)CC(Br)C1                   57.966667
# Brc1c(Br)c(Br)c(Oc2c(Br)c(Br)c(Br)c(Br)c2Br)c(B...     81.333333
# Brc1ccccc1                                             83.333333
# C#CC(C)(C)O                                            91.333333
# C#CC(C)O                                               75.000000

# %%
#
moldf['Outcome']=np.where(moldf['Outcome'] >= '1', 1, -1)
moldf['Prediction']=np.where(moldf['Prediction']== 'Toxic', 1, -1)
moldf['Confiability']= moldf['Confiability'].values/100
#
moldf_acute_inhalation_maccs = moldf.copy()
#del moldf_acute_inhalation['Outcome']
moldf_acute_inhalation_maccs= moldf_acute_inhalation_maccs.rename(columns={"Prediction": "MACCS_Pred", "Confiability": "MACCS_Conf"})
fps_acute_inhalation_maccs= np.vstack(acute_inhalation_data_maccs['fpDF']['FingerPrint'].values)
X, y = train_test_split( fps_acute_inhalation_maccs , test_size=0.2, random_state=42)
acute_inhalation_maccs_AD_limit= (np.average(acute_inhalation_data_maccs['applM'])-(1*(np.std(acute_inhalation_data_maccs['applM']))))
acute_inhalation_maccs_K= acute_inhalation_data_maccs["k"]
acute_inhalation_maccs_AD = getNeighborsDitance(X,fps_acute_inhalation_maccs , acute_inhalation_maccs_K)
moldf_acute_inhalation_maccs['MACCS AD']= np.where(acute_inhalation_maccs_AD >=acute_inhalation_maccs_AD_limit, 1, 0)
moldf_acute_inhalation_maccs.head(100)
# Out:
#                                                     Outcome  MACCS_Pred  \
# SMILES
# BrC1CC(Br)CC(Br)CC(Br)CC(Br)CC(Br)C1                     -1          -1
# Brc1c(Br)c(Br)c(Oc2c(Br)c(Br)c(Br)c(Br)c2Br)c(B...       -1          -1
# Brc1ccccc1                                               -1          -1
# C#CC(C)(C)O                                              -1          -1
# C#CC(C)O                                                  1          -1
# ...                                                     ...         ...
# C=CCOC(=O)CC(C)=O                                        -1           1
# C=CCOCC1CO1                                               1           1
# C=CCl                                                    -1          -1
# C=CN1CCCC1=O                                              1          -1
# C=CN1CCN(C=C)C1=O                                        -1          -1
#
#                                                     MACCS_Conf  MACCS AD
# SMILES
# BrC1CC(Br)CC(Br)CC(Br)CC(Br)CC(Br)C1                  0.579667         1
# Brc1c(Br)c(Br)c(Oc2c(Br)c(Br)c(Br)c(Br)c2Br)c(B...    0.813333         1
# Brc1ccccc1                                            0.833333         1
# C#CC(C)(C)O                                           0.913333         1
# C#CC(C)O                                              0.750000         1
# ...                                                        ...       ...
# C=CCOC(=O)CC(C)=O                                     0.513333         1
# C=CCOCC1CO1                                           0.563333         1
# C=CCl                                                 0.515690         1
# C=CN1CCCC1=O                                          0.593333         1
# C=CN1CCN(C=C)C1=O                                     0.550000         1
#
# [100 rows x 4 columns]

# %%
moldf_acute_inhalation_maccs['MACCS Pred'] = moldf_acute_inhalation_maccs[['MACCS_Pred', 'MACCS_Conf']].prod(1)
moldf_acute_inhalation_maccs['MACCS Pred AD'] = moldf_acute_inhalation_maccs[['MACCS_Pred', 'MACCS_Conf','MACCS AD']].prod(1)
moldf_acute_inhalation_maccs.head()
moldf_acute_inhalation_maccs= moldf_acute_inhalation_maccs[['Outcome','MACCS Pred', 'MACCS Pred AD']]
del moldf_acute_inhalation_maccs['Outcome']
moldf_acute_inhalation_maccs.head(200)
# Out:
#                                                     MACCS Pred  MACCS Pred AD
# SMILES
# BrC1CC(Br)CC(Br)CC(Br)CC(Br)CC(Br)C1                 -0.579667      -0.579667
# Brc1c(Br)c(Br)c(Oc2c(Br)c(Br)c(Br)c(Br)c2Br)c(B...   -0.813333      -0.813333
# Brc1ccccc1                                           -0.833333      -0.833333
# C#CC(C)(C)O                                          -0.913333      -0.913333
# C#CC(C)O                                             -0.750000      -0.750000
# ...                                                        ...            ...
# CC1=CC(=O)CC(C)(C)C1                                  0.716667       0.716667
# CC1=CC(C)(C)CC(=O)C1                                  0.750000       0.750000
# CC1C2CC(CC2C2CCC(O)CC2)C1(C)C                        -0.820000      -0.820000
# CC1C2CC(CC2C2CCCC(O)C2)C1(C)C                        -0.850000      -0.000000
# CC1CC(=O)CC(C)(C)C1                                   0.776667       0.776667
#
# [200 rows x 2 columns]

# %% [markdown]
# ##  Acute Inhalation - mordred

# %%
acute_inhalation_modred = joblib.load('Projeto_2_Acute_Inhalation/model/Modelo_AcuteInhal_mordred.pkl')
acute_inhalation_data_mordred= pd.read_pickle('Projeto_2_Acute_Inhalation/model/Dados_adicionais_AcuteInhal_mordred.pbz2', compression="bz2")
moldf= acute_inhalation_data_mordred['molDF']
del moldf['mol']
moldf.head()
# Out:
#                                                     Outcome Prediction  \
# SMILES
# BrC1CC(Br)CC(Br)CC(Br)CC(Br)CC(Br)C1                    0.0  Non-Toxic
# Brc1c(Br)c(Br)c(Oc2c(Br)c(Br)c(Br)c(Br)c2Br)c(B...      0.0  Non-Toxic
# Brc1ccccc1                                              0.0  Non-Toxic
# C#CC(C)(C)O                                             0.0  Non-Toxic
# C#CC(C)O                                                1.0  Non-Toxic
#
#                                                     Confiability
# SMILES
# BrC1CC(Br)CC(Br)CC(Br)CC(Br)CC(Br)C1                        54.0
# Brc1c(Br)c(Br)c(Oc2c(Br)c(Br)c(Br)c(Br)c2Br)c(B...          50.0
# Brc1ccccc1                                                  53.0
# C#CC(C)(C)O                                                 72.0
# C#CC(C)O                                                    55.0

# %%
#
moldf['Outcome']=np.where(moldf['Outcome'] >= 1, 1, -1)
moldf['Prediction']=np.where(moldf['Prediction']== 'Toxic', 1, -1)
moldf['Confiability']= moldf['Confiability'].values/100
#
moldf_acute_inhalation_mordred = moldf.copy()
#del moldf_acute_inhalation['Outcome']
moldf_acute_inhalation_mordred= moldf_acute_inhalation_mordred.rename(columns={"Prediction": "Mordred_Pred", "Confiability": "Mordred_Conf"})
fps_acute_inhalation_mordred= np.vstack(acute_inhalation_data_mordred['fpDF']['FingerPrint'].values)
X, y = train_test_split( fps_acute_inhalation_mordred , test_size=0.2, random_state=42)
acute_inhalation_mordred_AD_limit= (np.average(acute_inhalation_data_mordred['applM'])-(1*(np.std(acute_inhalation_data_mordred['applM']))))
acute_inhalation_mordred_K= acute_inhalation_data_mordred["k"]
acute_inhalation_mordred_AD = getNeighborsDitance(X,fps_acute_inhalation_mordred , acute_inhalation_mordred_K)
moldf_acute_inhalation_mordred['Mordred AD']= np.where(acute_inhalation_mordred_AD >=acute_inhalation_mordred_AD_limit, 1, 0)
moldf_acute_inhalation_mordred.head(100)
# Out:
#                                                     Outcome  Mordred_Pred  \
# SMILES
# BrC1CC(Br)CC(Br)CC(Br)CC(Br)CC(Br)C1                     -1            -1
# Brc1c(Br)c(Br)c(Oc2c(Br)c(Br)c(Br)c(Br)c2Br)c(B...       -1            -1
# Brc1ccccc1                                               -1            -1
# C#CC(C)(C)O                                              -1            -1
# C#CC(C)O                                                  1            -1
# ...                                                     ...           ...
# C=CCOC(=O)CC(C)=O                                        -1             1
# C=CCOCC1CO1                                               1             1
# C=CCl                                                    -1             1
# C=CN1CCCC1=O                                              1             1
# C=CN1CCN(C=C)C1=O                                        -1             1
#
#                                                     Mordred_Conf  Mordred AD
# SMILES
# BrC1CC(Br)CC(Br)CC(Br)CC(Br)CC(Br)C1                        0.54           1
# Brc1c(Br)c(Br)c(Oc2c(Br)c(Br)c(Br)c(Br)c2Br)c(B...          0.50           1
# Brc1ccccc1                                                  0.53           1
# C#CC(C)(C)O                                                 0.72           0
# C#CC(C)O                                                    0.55           1
# ...                                                          ...         ...
# C=CCOC(=O)CC(C)=O                                           0.57           1
# C=CCOCC1CO1                                                 0.69           0
# C=CCl                                                       0.75           1
# C=CN1CCCC1=O                                                0.82           1
# C=CN1CCN(C=C)C1=O                                           0.77           1
#
# [100 rows x 4 columns]

# %%
moldf_acute_inhalation_mordred['Mordred Pred'] = moldf_acute_inhalation_mordred[['Mordred_Pred', 'Mordred_Conf']].prod(1)
moldf_acute_inhalation_mordred['Mordred Pred AD'] = moldf_acute_inhalation_mordred[['Mordred_Pred', 'Mordred_Conf','Mordred AD']].prod(1)
moldf_acute_inhalation_mordred.head()
moldf_acute_inhalation_mordred= moldf_acute_inhalation_mordred[['Outcome','Mordred Pred', 'Mordred Pred AD']]
del moldf_acute_inhalation_mordred['Outcome']
moldf_acute_inhalation_mordred.head(200)
# Out:
#                                                     Mordred Pred  \
# SMILES
# BrC1CC(Br)CC(Br)CC(Br)CC(Br)CC(Br)C1                       -0.54
# Brc1c(Br)c(Br)c(Oc2c(Br)c(Br)c(Br)c(Br)c2Br)c(B...         -0.50
# Brc1ccccc1                                                 -0.53
# C#CC(C)(C)O                                                -0.72
# C#CC(C)O                                                   -0.55
# ...                                                          ...
# CC1=CC(=O)CC(C)(C)C1                                        0.76
# CC1=CC(C)(C)CC(=O)C1                                        0.64
# CC1C2CC(CC2C2CCC(O)CC2)C1(C)C                              -0.80
# CC1C2CC(CC2C2CCCC(O)C2)C1(C)C                              -0.78
# CC1CC(=O)CC(C)(C)C1                                         0.71
#
#                                                     Mordred Pred AD
# SMILES
# BrC1CC(Br)CC(Br)CC(Br)CC(Br)CC(Br)C1                          -0.54
# Brc1c(Br)c(Br)c(Oc2c(Br)c(Br)c(Br)c(Br)c2Br)c(B...            -0.50
# Brc1ccccc1                                                    -0.53
# C#CC(C)(C)O                                                   -0.00
# C#CC(C)O                                                      -0.55
# ...                                                             ...
# CC1=CC(=O)CC(C)(C)C1                                           0.76
# CC1=CC(C)(C)CC(=O)C1                                           0.64
# CC1C2CC(CC2C2CCC(O)CC2)C1(C)C                                 -0.00
# CC1C2CC(CC2C2CCCC(O)C2)C1(C)C                                 -0.00
# CC1CC(=O)CC(C)(C)C1                                            0.71
#
# [200 rows x 2 columns]

# %%
moldf_global=pd.concat([moldf_acute_inhalation_morgan, moldf_acute_inhalation_maccs, 
                       moldf_acute_inhalation_mordred ], axis=1, 
                      join_axes=[moldf_acute_inhalation_morgan.index])
moldf_global.head()
# Out:
#                                                     Outcome  Morgan Pred  \
# SMILES
# BrC1CC(Br)CC(Br)CC(Br)CC(Br)CC(Br)C1                     -1         0.61
# Brc1c(Br)c(Br)c(Oc2c(Br)c(Br)c(Br)c(Br)c2Br)c(B...       -1        -0.78
# Brc1ccccc1                                               -1        -0.75
# C#CC(C)(C)O                                              -1         0.57
# C#CC(C)O                                                  1         0.74
#
#                                                     Morgan Pred AD  \
# SMILES
# BrC1CC(Br)CC(Br)CC(Br)CC(Br)CC(Br)C1                          0.61
# Brc1c(Br)c(Br)c(Oc2c(Br)c(Br)c(Br)c(Br)c2Br)c(B...           -0.78
# Brc1ccccc1                                                   -0.75
# C#CC(C)(C)O                                                   0.00
# C#CC(C)O                                                      0.74
#
#                                                     MACCS Pred  MACCS Pred AD  \
# SMILES
# BrC1CC(Br)CC(Br)CC(Br)CC(Br)CC(Br)C1                 -0.579667      -0.579667
# Brc1c(Br)c(Br)c(Oc2c(Br)c(Br)c(Br)c(Br)c2Br)c(B...   -0.813333      -0.813333
# Brc1ccccc1                                           -0.833333      -0.833333
# C#CC(C)(C)O                                          -0.913333      -0.913333
# C#CC(C)O                                             -0.750000      -0.750000
#
#                                                     Mordred Pred  \
# SMILES
# BrC1CC(Br)CC(Br)CC(Br)CC(Br)CC(Br)C1                       -0.54
# Brc1c(Br)c(Br)c(Oc2c(Br)c(Br)c(Br)c(Br)c2Br)c(B...         -0.50
# Brc1ccccc1                                                 -0.53
# C#CC(C)(C)O                                                -0.72
# C#CC(C)O                                                   -0.55
#
#                                                     Mordred Pred AD
# SMILES
# BrC1CC(Br)CC(Br)CC(Br)CC(Br)CC(Br)C1                          -0.54
# Brc1c(Br)c(Br)c(Oc2c(Br)c(Br)c(Br)c(Br)c2Br)c(B...            -0.50
# Brc1ccccc1                                                    -0.53
# C#CC(C)(C)O                                                   -0.00
# C#CC(C)O                                                      -0.55

# %%
moldf_global['Consensus Conf'] = moldf_global[['Morgan Pred','MACCS Pred','Mordred Pred']].mean(1)
moldf_global['Consensus']=np.where(moldf_global['Consensus Conf']>= 0, 1, -1)
moldf_global['Consensus Conf AD'] = moldf_global[['Morgan Pred AD','MACCS Pred AD','Mordred Pred AD']].mean(1)
moldf_global['Consensus AD']=np.where(moldf_global['Consensus Conf AD']>= 0, 1, -1)

# %%
moldf_global
# Out:
#                                                     Outcome  Morgan Pred  \
# SMILES
# BrC1CC(Br)CC(Br)CC(Br)CC(Br)CC(Br)C1                     -1         0.61
# Brc1c(Br)c(Br)c(Oc2c(Br)c(Br)c(Br)c(Br)c2Br)c(B...       -1        -0.78
# Brc1ccccc1                                               -1        -0.75
# C#CC(C)(C)O                                              -1         0.57
# C#CC(C)O                                                  1         0.74
# ...                                                     ...          ...
# c1ccc2c(c1)CCNC2                                          1         0.51
# c1ccc2n[nH]nc2c1                                          1        -0.56
# c1ccc2scnc2c1                                             1         0.80
# c1ccccc1                                                 -1         0.66
# c1ccncc1                                                  1        -0.65
#
#                                                     Morgan Pred AD  \
# SMILES
# BrC1CC(Br)CC(Br)CC(Br)CC(Br)CC(Br)C1                          0.61
# Brc1c(Br)c(Br)c(Oc2c(Br)c(Br)c(Br)c(Br)c2Br)c(B...           -0.78
# Brc1ccccc1                                                   -0.75
# C#CC(C)(C)O                                                   0.00
# C#CC(C)O                                                      0.74
# ...                                                            ...
# c1ccc2c(c1)CCNC2                                              0.00
# c1ccc2n[nH]nc2c1                                             -0.56
# c1ccc2scnc2c1                                                 0.80
# c1ccccc1                                                      0.00
# c1ccncc1                                                     -0.00
#
#                                                     MACCS Pred  MACCS Pred AD  \
# SMILES
# BrC1CC(Br)CC(Br)CC(Br)CC(Br)CC(Br)C1                 -0.579667      -0.579667
# Brc1c(Br)c(Br)c(Oc2c(Br)c(Br)c(Br)c(Br)c2Br)c(B...   -0.813333      -0.813333
# Brc1ccccc1                                           -0.833333      -0.833333
# C#CC(C)(C)O                                          -0.913333      -0.913333
# C#CC(C)O                                             -0.750000      -0.750000
# ...                                                        ...            ...
# c1ccc2c(c1)CCNC2                                      0.753333       0.753333
# c1ccc2n[nH]nc2c1                                      0.613333       0.613333
# c1ccc2scnc2c1                                         0.710000       0.710000
# c1ccccc1                                             -0.511667      -0.000000
# c1ccncc1                                              0.906667       0.906667
#
#                                                     Mordred Pred  \
# SMILES
# BrC1CC(Br)CC(Br)CC(Br)CC(Br)CC(Br)C1                       -0.54
# Brc1c(Br)c(Br)c(Oc2c(Br)c(Br)c(Br)c(Br)c2Br)c(B...         -0.50
# Brc1ccccc1                                                 -0.53
# C#CC(C)(C)O                                                -0.72
# C#CC(C)O                                                   -0.55
# ...                                                          ...
# c1ccc2c(c1)CCNC2                                            0.62
# c1ccc2n[nH]nc2c1                                            0.70
# c1ccc2scnc2c1                                               0.83
# c1ccccc1                                                   -0.75
# c1ccncc1                                                    0.82
#
#                                                     Mordred Pred AD  \
# SMILES
# BrC1CC(Br)CC(Br)CC(Br)CC(Br)CC(Br)C1                          -0.54
# Brc1c(Br)c(Br)c(Oc2c(Br)c(Br)c(Br)c(Br)c2Br)c(B...            -0.50
# Brc1ccccc1                                                    -0.53
# C#CC(C)(C)O                                                   -0.00
# C#CC(C)O                                                      -0.55
# ...                                                             ...
# c1ccc2c(c1)CCNC2                                               0.62
# c1ccc2n[nH]nc2c1                                               0.70
# c1ccc2scnc2c1                                                  0.83
# c1ccccc1                                                      -0.00
# c1ccncc1                                                       0.82
#
#                                                     Consensus Conf  Consensus  \
# SMILES
# BrC1CC(Br)CC(Br)CC(Br)CC(Br)CC(Br)C1                     -0.169889         -1
# Brc1c(Br)c(Br)c(Oc2c(Br)c(Br)c(Br)c(Br)c2Br)c(B...       -0.697778         -1
# Brc1ccccc1                                               -0.704444         -1
# C#CC(C)(C)O                                              -0.354444         -1
# C#CC(C)O                                                 -0.186667         -1
# ...                                                            ...        ...
# c1ccc2c(c1)CCNC2                                          0.627778          1
# c1ccc2n[nH]nc2c1                                          0.251111          1
# c1ccc2scnc2c1                                             0.780000          1
# c1ccccc1                                                 -0.200556         -1
# c1ccncc1                                                  0.358889          1
#
#                                                     Consensus Conf AD  \
# SMILES
# BrC1CC(Br)CC(Br)CC(Br)CC(Br)CC(Br)C1                        -0.169889
# Brc1c(Br)c(Br)c(Oc2c(Br)c(Br)c(Br)c(Br)c2Br)c(B...          -0.697778
# Brc1ccccc1                                                  -0.704444
# C#CC(C)(C)O                                                 -0.304444
# C#CC(C)O                                                    -0.186667
# ...                                                               ...
# c1ccc2c(c1)CCNC2                                             0.457778
# c1ccc2n[nH]nc2c1                                             0.251111
# c1ccc2scnc2c1                                                0.780000
# c1ccccc1                                                     0.000000
# c1ccncc1                                                     0.575556
#
#                                                     Consensus AD
# SMILES
# BrC1CC(Br)CC(Br)CC(Br)CC(Br)CC(Br)C1                          -1
# Brc1c(Br)c(Br)c(Oc2c(Br)c(Br)c(Br)c(Br)c2Br)c(B...            -1
# Brc1ccccc1                                                    -1
# C#CC(C)(C)O                                                   -1
# C#CC(C)O                                                      -1
# ...                                                          ...
# c1ccc2c(c1)CCNC2                                               1
# c1ccc2n[nH]nc2c1                                               1
# c1ccc2scnc2c1                                                  1
# c1ccccc1                                                       1
# c1ccncc1                                                       1
#
# [680 rows x 11 columns]

# %%
run_statistics(moldf_global['Outcome'], moldf_global['Consensus'], label="Consensus external 5-fold CV", coverage=100)
# Out:
# ########################################
# #   Unbalanced Statistical Parameters  #
# ########################################
# Accuracy: 0.74
# Area under the Curve (AUC): 0.74
# ########################################
# #   Balanced Statistical Parameters    #
# ########################################
# Correct Classification Rate (CCR): 0.74
# Weighted Kappa:  0.48
# ########################################
# #            Positive Class            #
# ########################################
# Sensitivity (Se): 0.69
# Positive Predictive Value (PPV): 0.77
# ########################################
# #            Negative Class            #
# ########################################
# Specificity (Sp): 0.8
# Negative Predictive Value (NPV): 0.72
# ########################################
# #     Other Statistical Parameters     #
# ########################################
# Precision:  0.77
# Recall:  0.69
# F1:  0.73
# ########################################
# #        Applicability Domain          #
# ########################################
# coverage:  100%

# %%
coverage= (len(moldf_global['Consensus AD'])*100/len(moldf))
run_statistics(moldf_global['Outcome'], moldf_global['Consensus AD'], 
               label="Consensus AD external 5-fold CV", coverage=int(coverage))
# Out:
# ########################################
# #   Unbalanced Statistical Parameters  #
# ########################################
# Accuracy: 0.73
# Area under the Curve (AUC): 0.73
# ########################################
# #   Balanced Statistical Parameters    #
# ########################################
# Correct Classification Rate (CCR): 0.74
# Weighted Kappa:  0.47
# ########################################
# #            Positive Class            #
# ########################################
# Sensitivity (Se): 0.7
# Positive Predictive Value (PPV): 0.75
# ########################################
# #            Negative Class            #
# ########################################
# Specificity (Sp): 0.77
# Negative Predictive Value (NPV): 0.72
# ########################################
# #     Other Statistical Parameters     #
# ########################################
# Precision:  0.75
# Recall:  0.7
# F1:  0.72
# ########################################
# #        Applicability Domain          #
# ########################################
# coverage:  100%
